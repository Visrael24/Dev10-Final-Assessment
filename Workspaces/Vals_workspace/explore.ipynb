# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../../Data/final_csv_all_data.csv')

# %%
df
# Out:
#     Year  kg_per_yr_per_capita  Production_in_tons  \
# 0   1961             13.760740           2813910.0
# 1   1962             14.116647           2872680.0
# 2   1963             13.753343           2656860.0
# 3   1964             13.410462           2522230.0
# 4   1965             13.526203           2649230.0
# 5   1966             13.969090           2422840.0
# 6   1967             13.320065           2310410.0
# 7   1968             14.852797           2413380.0
# 8   1969             13.959552           2430900.0
# 9   1970             15.192157           2842950.0
# 10  1971             14.664470           2908000.0
# 11  1972             16.614815           2796510.0
# 12  1973             15.980325           2837670.0
# 13  1974             15.358340           2894450.0
# 14  1975             14.665650           2906840.0
# 15  1976             16.179398           3112150.0
# 16  1977             15.992288           3049560.0
# ...

# %%
df = df[df['Code'] == 'USA']

# %%
df.drop(['Entity', 'Code'], inplace=True, axis=1)
df = df.dropna().reset_index(drop=True)

# %%
Production_in_tons = df['Production_in_tons']
Production_in_tons

# %%
Production_in_tons
data_points = Production_in_tons

# %%
percentage_increase = [(data_points[i+1] - data_points[i]) / data_points[i] * 100 for i in range(len(data_points)-1)]
average_increase = np.mean(percentage_increase)
print("Average Percentage Increase: {:.2f}%".format(average_increase))

# %%
x = 5349930.0
for i in range(20):
    x = x + (x * .0125)
print(x)

# %%
kg_per_cap = df['kg_per_yr_per_capita']

# %%
kg_per_cap.tail(1)
# Out:
# 59    22.45492
# Name: kg_per_yr_per_capita, dtype: float64

# %%
kg_per_cap
data_points = kg_per_cap
percentage_increase = [(data_points[i+1] - data_points[i]) / data_points[i] * 100 for i in range(len(data_points)-1)]
average_increase = np.mean(percentage_increase)
print("Average Percentage Increase: {:.2f}%".format(average_increase))
# Out:
# Average Percentage Increase: 0.96%

# %%
x = 22.45492
for i in range(20):
    x = x + (x * .0096)
print(x)
# Out:
# 27.18306040179777

# %% [markdown]
# # attempt at prediction with ML
# so the predicted values in the next 20 years for production, consumption, and population:
# 6858809, 27.183, 400mil
#
# I'm going to take these values and see what the predicted life expectany is using the ML model, and compare it to actual prediction.
