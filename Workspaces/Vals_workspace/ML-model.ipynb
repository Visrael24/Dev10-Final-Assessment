# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../../Data/final_csv_all_data.csv')

# %%
df
# Out:
#            Entity Code  Year  kg_per_yr_per_capita  Production_in_tons  \
# 0     Afghanistan  AFG  1961              0.030559               300.0
# 1     Afghanistan  AFG  1962              0.030578               300.0
# 2     Afghanistan  AFG  1963              0.030598               300.0
# 3     Afghanistan  AFG  1964              0.030614               300.0
# 4     Afghanistan  AFG  1965              0.030627               300.0
# ...           ...  ...   ...                   ...                 ...
# 9305     Zimbabwe  ZWE  2016              3.679239             25800.0
# 9306     Zimbabwe  ZWE  2017              3.397224             26800.0
# 9307     Zimbabwe  ZWE  2018              3.117559             32300.0
# 9308     Zimbabwe  ZWE  2019              2.870986             29230.0
# 9309     Zimbabwe  ZWE  2020              2.817092             29230.0
#
#       Population (historical estimates)  Life_Expectancy_years continent
# 0                               8790140                  32.96      Asia
# 1                               8969055                  33.47      Asia
# 2                               9157463                  33.97      Asia
# 3                               9355510                  34.46      Asia
# 4                               9565154                  34.95      Asia
# ...                                 ...                    ...       ...
# 9305                           14452705                  60.29    Africa
# 9306                           14751101                  60.81    Africa
# 9307                           15052191                  61.20    Africa
# 9308                           15354606                  61.49    Africa
# 9309                           15669663                  61.74    Africa
#
# [9310 rows x 8 columns]

# %%
# df = df[df['Code'] == 'USA'].reset_index(drop=True)
df
# Out:
#            Entity Code  Year  kg_per_yr_per_capita  Production_in_tons  \
# 0     Afghanistan  AFG  1961              0.030559               300.0
# 1     Afghanistan  AFG  1962              0.030578               300.0
# 2     Afghanistan  AFG  1963              0.030598               300.0
# 3     Afghanistan  AFG  1964              0.030614               300.0
# 4     Afghanistan  AFG  1965              0.030627               300.0
# ...           ...  ...   ...                   ...                 ...
# 9305     Zimbabwe  ZWE  2016              3.679239             25800.0
# 9306     Zimbabwe  ZWE  2017              3.397224             26800.0
# 9307     Zimbabwe  ZWE  2018              3.117559             32300.0
# 9308     Zimbabwe  ZWE  2019              2.870986             29230.0
# 9309     Zimbabwe  ZWE  2020              2.817092             29230.0
#
#       Population (historical estimates)  Life_Expectancy_years continent
# 0                               8790140                  32.96      Asia
# 1                               8969055                  33.47      Asia
# 2                               9157463                  33.97      Asia
# 3                               9355510                  34.46      Asia
# 4                               9565154                  34.95      Asia
# ...                                 ...                    ...       ...
# 9305                           14452705                  60.29    Africa
# 9306                           14751101                  60.81    Africa
# 9307                           15052191                  61.20    Africa
# 9308                           15354606                  61.49    Africa
# 9309                           15669663                  61.74    Africa
#
# [9310 rows x 8 columns]

# %%
X = df[['Production_in_tons', 'kg_per_yr_per_capita']]
y = df['Life_Expectancy_years']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
# print('Mean Squared Error:', mse)
print(model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25240/3424549165.py in <module>
#       3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=2)
#       4 model = LinearRegression()
# ----> 5 model.fit(X_train, y_train)
#       6 y_pred = model.predict(X_test)
#       7 mse = mean_squared_error(y_test, y_pred)
#
# c:\Users\valor\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# c:\Users\valor\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# c:\Users\valor\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\valor\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     878                     estimator=estimator)
#     879     if multi_output:
# --> 880         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#     881                         ensure_2d=False, dtype=None)
#     882     else:
#
# c:\Users\valor\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\valor\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718
#     719         if force_all_finite:
# --> 720             _assert_all_finite(array,
#     721                                allow_nan=force_all_finite == 'allow-nan')
#     722
#
# c:\Users\valor\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
