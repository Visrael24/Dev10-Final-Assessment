# %%
import pandas as pd

# %%
pop2009 = pd.read_csv('../Becca_workspace/data/pop200to2009.csv', encoding='ISO-8859-1')
pop2019 = pd.read_csv('../Becca_workspace/data/pop2010to2019.csv', encoding='ISO-8859-1')
pop2021 = pd.read_csv('../Becca_workspace/data/pop2020to2021.csv', encoding='ISO-8859-1')

# %% [markdown]
# ###TRANSFORMATION

# %% [markdown]
# ##POP2006-2009

# %%
pop2009[['NewName', 'city']] = pop2009.NAME.str.split(" city", expand = True)

# %%
pop2009[['CityName', 'town']] = pop2009.NewName.str.split(" town", expand = True)

# %%
pop2009.drop(pop2009[pop2009['SUMLEV'] != 162].index, inplace = True)

# %%
pop2009.drop(['PLACE', 'SUMLEV', 'COUNTY', 'COUSUB', 'NAME', 'POPCENSUS_2000', 'POPBASE_2000', 'POP_2000', 'POP_2001', 'POP_2002', 'POP_2003', 'POP_2004', 'POP_2005', 'NewName', 'city', 'town'], axis=1, inplace = True)

# %%
pop2009.to_csv('../Becca_workspace/data/cleaned_pop2009.csv', index=False)

# %% [markdown]
# #POP2010-2019

# %%
pop2019[['NewName', 'city']] = pop2019.NAME.str.split(" city", expand = True)

# %%
pop2019[['CityName', 'town']] = pop2019.NewName.str.split(" town", expand = True)

# %%
pop2019.drop(pop2019[pop2019['SUMLEV'] != 162].index, inplace = True)

# %%
pop2019.drop(['PLACE', 'STNAME', 'SUMLEV', 'COUNTY', 'COUSUB', 'CONCIT', 'PRIMGEO_FLAG', 'FUNCSTAT', 'NAME', 'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2017', 'POPESTIMATE2018', 'POPESTIMATE2019', 'NewName', 'city', 'town'], axis=1, inplace = True)

# %%
pop2019.to_csv('../Becca_workspace/data/cleaned_pop2016.csv', index=False)

# %%
pop2009
# Out:
#        STATE STATENAME  POP_2006  POP_2007  POP_2008  POP_2009    CityName
# 1          1   Alabama      2926      2939      2931      2934   Abbeville
# 2          1   Alabama      4851      4797      4789      4782  Adamsville
# 3          1   Alabama       713       717       711       711     Addison
# 4          1   Alabama       434       437       437       434       Akron
# 5          1   Alabama     28369     28810     29337     29861   Alabaster
# ...      ...       ...       ...       ...       ...       ...         ...
# 81552     56   Wyoming       264       270       272       310   Wamsutter
# 81553     56   Wyoming      3365      3331      3280      3236   Wheatland
# 81554     56   Wyoming      4884      4971      4985      5054     Worland
# 81555     56   Wyoming      1479      1517      1474      1550      Wright
# 81556     56   Wyoming       161       161       162       164       Yoder
#
# [19510 rows x 7 columns]

# %%
pop2019.columns
# Out:
# Index(['STATE', 'POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012',
#        'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015',
#        'POPESTIMATE2016', 'CityName'],
#       dtype='object')

# %% [markdown]
# ###MERGE 2009 and 2016

# %%
pop_final = pd.merge(pop2019, pop2009, on=['CityName', 'STATE'], how='inner')

# %%
pop_final.drop(['STATE'], axis=1, inplace = True)

# %%
pop_final.columns
# Out:
# Index(['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012',
#        'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015',
#        'POPESTIMATE2016', 'CityName', 'STATENAME', 'POP_2006', 'POP_2007',
#        'POP_2008', 'POP_2009'],
#       dtype='object')

# %%
pop_final = pop_final[['STATENAME', 'CityName', 'POP_2006', 'POP_2007', 'POP_2008', 'POP_2009', 'POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016']]

# %%
pop_final
# Out:
#       STATENAME    CityName  POP_2006  POP_2007  POP_2008  POP_2009  \
# 0       Alabama   Abbeville      2926      2939      2931      2934
# 1       Alabama  Adamsville      4851      4797      4789      4782
# 2       Alabama     Addison       713       717       711       711
# 3       Alabama       Akron       434       437       437       434
# 4       Alabama   Alabaster     28369     28810     29337     29861
# ...         ...         ...       ...       ...       ...       ...
# 19371   Wyoming   Wamsutter       264       270       272       310
# 19372   Wyoming   Wheatland      3365      3331      3280      3236
# 19373   Wyoming     Worland      4884      4971      4985      5054
# 19374   Wyoming      Wright      1479      1517      1474      1550
# 19375   Wyoming       Yoder       161       161       162       164
#
#        POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0                 2699             2694             2643             2628
# ...

# %%
pop_final.rename(columns = {'STATENAME':'State', 'CityName':'City', 'POPESTIMATE2010':'POP_2010', 'POPESTIMATE2011':'POP_2011', 'POPESTIMATE2012':'POP_2012', 'POPESTIMATE2013':'POP_2013', 'POPESTIMATE2014':'POP_2014', 'POPESTIMATE2015':'POP_2015', 'POPESTIMATE2016':'POP_2016'}, inplace = True)

# %%
pop_final
# Out:
#          State        City  POP_2006  POP_2007  POP_2008  POP_2009  POP_2010  \
# 0      Alabama   Abbeville      2926      2939      2931      2934      2699
# 1      Alabama  Adamsville      4851      4797      4789      4782      4500
# 2      Alabama     Addison       713       717       711       711       751
# 3      Alabama       Akron       434       437       437       434       355
# 4      Alabama   Alabaster     28369     28810     29337     29861     31209
# ...        ...         ...       ...       ...       ...       ...       ...
# 19371  Wyoming   Wamsutter       264       270       272       310       450
# 19372  Wyoming   Wheatland      3365      3331      3280      3236      3622
# 19373  Wyoming     Worland      4884      4971      4985      5054      5487
# 19374  Wyoming      Wright      1479      1517      1474      1550      1810
# 19375  Wyoming       Yoder       161       161       162       164       152
#
# ...

# %%
pop_final.to_csv('../Becca_workspace/data/pop_cleaned.csv', index=False)
