# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../../Data/Fish/capture-fisheries-vs-aquaculture.csv')

# %%
df.drop(df[df['Code'] != 'USA', ].index, inplace=True)

# %%
df.drop(['Entity'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Code', 'Year', 'Aquaculture production (metric tons)',
#        'Capture fisheries production (metric tons)'],
#       dtype='object')

# %%
df.rename(columns = {'Aquaculture production (metric tons)':'Aquaculture Production', 'Capture fisheries production (metric tons)':'Captured Fish'}, inplace=True)

# %%
df
# Out:
#       Code  Year  Aquaculture Production  Captured Fish
# 12022  USA  1960                104421.0      2755715.0
# 12023  USA  1961                102547.0      2979093.0
# 12024  USA  1962                109961.0      2995674.0
# 12025  USA  1963                122697.0      2741650.0
# 12026  USA  1964                123884.0      2585660.0
# 12027  USA  1965                132578.0      2702785.0
# 12028  USA  1966                114236.0      2495433.0
# 12029  USA  1967                127299.0      2377789.0
# 12030  USA  1968                131115.0      2470105.0
# 12031  USA  1969                116768.0      2478221.0
# 12032  USA  1970                168681.0      2836550.0
# 12033  USA  1971                165590.0      2917107.0
# 12034  USA  1972                173630.0      2810040.0
# 12035  USA  1973                170320.0      2836981.0
# 12036  USA  1974                167039.0      2919015.0
# 12037  USA  1975                218459.0      2876146.0
# ...

# %%
df.to_csv('../../../Data/Fish/farmsandcapture_cleaned.csv', index=False)
